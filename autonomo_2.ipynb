# %% [markdown]
# PROGRAMACIÓN 2
# Actividad Autónoma 2
# Unidad 1: Fundamentos de la Programación Orientada a
# Objetos (POO)
# Tema 2: Integración de Principios de OOP, Patrones de Diseño
# y Sobrecarga de Operadores
# Nombres:  MISHELL RAMOS
# Fecha:    08-05-2025
# Carrera:  CIENCIA DE DATOS E INTELIGENCIA ARTIFICIAL
# Periodo académico: 2025
# Semestre: SEGUNDO

# %% [markdown]
# 1. Conceptos fundamentales de Programación Orientada a Objetos
# (OOP) en Python:
# • Abstracción
# • Encapsulamiento
# • Herencia
# • Polimorfismo
# 2. Sobrecarga de operadores en Python:
# • Métodos especiales como __eq__ y __add__
# 3. Patrones de diseño básicos:
# • Strategy Pattern
# • Decorator Pattern
# • Singleton Pattern
# 4. Uso de UML para diseño de software:
# • Diagrama de clases
# • Relaciones (herencia, composición, asociación)
# 5. Buenas prácticas de programación en Python:
# • Organización modular del código
# • Uso de getters y setters
# • Documentación de clases y métodos con docstrings

# %% [markdown]
# UML
# https://drive.google.com/file/d/1WfyY1lpsvJmajxrhR_A-LIfBvuwX4J_C/view?usp=sharing

# %%
from abc import ABC, abstractclassmethod
# estrategias
class estrategia(ABC):
    @abstractclassmethod
    def conducir(self):
        pass
class conduccionEconomica(estrategia):
    def conducir(self):
        return "conducion"
class conducciondeportiva(estrategia):
    def conducir(self):
        return "la conducion deportiva es:"
# clase base
class vehiculos(ABC):
 def __init__(self, unico, modelo, velocidad, capacidad, estrategia, conducir):
    self.unico = unico
    self.modelo = modelo
    self.velocidad = velocidad
    self.capacidad = capacidad
    self.estrategia = estrategia
    self.conducir = conducir
    self.estrategia = conduccionEconomica()
# los metodos
def modelo(self):
 return self.modelo

def velocidad(self):
    return self.velocidad 

def estrategia(self, estrategia):
     self.estrategia = estrategia

def conducir(self):
    return self.estrategia.conducir()

@abstractclassmethod

def acelerar(self, velocidad):
    self.velocidad += velocidad

def frenar(self, velocidad):
    self.velocidad -= velocidad

def estado(self):
 pass

 def __eq__(self, otro):
    return isinstance(otro, vehiculos)    \
        
 self.modelo == otro.modelo  and  self.velocidad == otro.velocidad

# subclase

class auto(vehiculos):
 def acelerar(self):
  return  F"Auto {self.modelo} acelerando suavemente. "

def frenar(self):
  return f" auto{self.modelo} frenanado suavemente. "

def estado(self):
    return f" auto.modelo {self.modelo}, velocidad maxima: {self.velocidad} km/h. "

class Camion(vehiculos):
    
 def __init__(self, unico, modelo, velocidad, capacidad):
  super().__init__(unico, modelo,velocidad,capacidad)
  self.remolque = False

def acelerar(self):
    return F" camion { self.modelo} acelerando "

def frenar(self):
    return f" camion {self.modelo} frenanado "

def estado(self):
    return f" camion modelo {self.modelo}, remolque: {'Sí'  if self.remolque else 'No'}. "

def engachar(self):
    self.engachar = true
    return "remolque enganchado"

class moto(vehiculos):
    def acelerar(self):
        return f" moto {self.modelo} acelerando "

def frenar(self):
    return f" moto {self.modelo} frenanado "

def estado(self):
    return f" moto modelo{self.modelo}, velocidad: {self.velocidad} km/h "

def maniobra(self):
    return f" la moto realozo una maniobra "

# patron

class vehiculos(vehiculos):
    def __init__(self,  vehiculo):
        self.vehiculos = vehiculo

def acelerar(self):
    return self.acelerar()

def frenar(self):
    return self.frenar()

def estado(self):
    return self.estado()

def conducir(self):
    return self.conducir()

def __eq__(self,otro):
    return self.vehiculos == otro

# especificos

class piloto(vehiculos):
    def conducir(self):
        return f" {self.vehiculos()} con piloto. "

class estacionamiento(vehiculos):
    def estado(self):
        return f" {self.vehiculos.estado()} asistencia de estacionamiento "

# control

class control:
 __instancia = None

def __init__(self):
 if control.instancia is None:
  raise excepcion(" ya existe una instancia " )
 self.vehiculos = []
 control.instancia = self

# metodo estatico
def obtenerinstancia():
    if control.instancia is None:
        control()
        return control.instancia

def agregarvehiculos(self,vehiculos: vehiculos):
    self.vehiculos.agregar(vehiculos)

def mostrarvehiculos(self):
    return informar(informar.estado( ) for v in self.vehiculos)

def __add__(self, vehiculos: vehiculos):
    self.agregar.vehiculos(vehiculos)
    return self

# uso
if __name__ == "__main__ " :
    camion = camion(" C1 ", "AXB FH", 120, 2000 )
    auto = automovil(" A1 ", "Chevrolet", 180, 500)
    moto = moto(" B1 ", " Tuko. 8236 ", 180, 200)

# estrategia
    moto.cambiar.estrategia(conducciondeportiva())
    camion.remolque()

# decorar
auto = piloto(auto)
moto = (moto)

# control
control = control()
control = control + auto
control = control + camion
control = control + moto

# mostrar estado
for estado in control.mostrar_vehiculos():
 print(estado)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 170
#     168 # control
#     169 control = control()
# --> 170 control = control + auto
#     171 control = control + camion
#     172 control = control + moto
#
# TypeError: unsupported operand type(s) for +: 'control' and 'piloto'
